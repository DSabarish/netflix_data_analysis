# %% [markdown]
# <a href="https://colab.research.google.com/github/DSabarish/netflix_data_analysis/blob/main/Netflix_07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Libraries and Data Quality Stats Function**

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Setting pandas options to display all columns and rows when printing dataframes
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# URL of the dataset to be read into a pandas dataframe
url = "https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv"
df = pd.read_csv(url)

df.info()
# Observations from the dataframe information
# The dataset contains 8807 entries
# [date_added , release_year] need to be converted to datetime type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
import pandas as pd

def data_quality_statistics(df):
    """
    This function takes a DataFrame as input and returns a DataFrame containing data quality statistics
    for each column in the DataFrame.

    Args:
      df: A Pandas DataFrame.

    Returns:
      A DataFrame containing data quality statistics for each column.
    """

    # Number of rows in the DataFrame
    num_rows = len(df)

    # List to store statistics for each column
    stats = []

    # Iterate over columns
    for col in df.columns:
        # Number of unique values
        num_unique = df[col].nunique()

        # Number of NaN values
        num_nan = df[col].isnull().sum()

        # Percentage of NaN values
        pct_nan = (num_nan / num_rows) * 100

        # Data type of the column
        data_type = df[col].dtype

        # Append statistics to the list
        stats.append({
            'Column': col,
            'Number of Rows': num_rows,
            'Number of Unique Values': num_unique,
            'Number of NaN': num_nan,
            'Percentage of NaN': round(pct_nan, 2),
            'Data Type': data_type,
            # Add more statistics here if needed
        })

    # Convert list of dictionaries to DataFrame
    stats_df = pd.DataFrame(stats)

    return stats_df

# Example usage:
# data_quality_statistics(df)

# %% [markdown]
# # **Basis Cleaning**

# %%
# Define the URL from which to read the CSV file
url = "https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv"
df = pd.read_csv(url)

# Remove leading and trailing spaces, extract only the date part, and convert to datetime format
# df["date_added"] = (df["date_added"]
#                     .str.strip()
#                     .apply(pd.to_datetime)
#                     .dt.date
#                     .apply(pd.to_datetime)
#                     )
# df["date_added"].head(3)

# df["date_added"].describe()

df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
# Define the URL from which to read the CSV file
url = "https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv"
df = pd.read_csv(url)

# Remove leading and trailing spaces, extract only the date part, and convert to datetime format
df["date_added"] = (df["date_added"]
                    .str.strip()
                    .apply(pd.to_datetime)
                    .dt.date
                    .apply(pd.to_datetime)
                    )
# df["date_added"].head(3)

df["date_added"].describe()
# Out:
# count                             8797
# mean     2019-05-17 05:59:08.436967168
# min                2008-01-01 00:00:00
# 25%                2018-04-06 00:00:00
# 50%                2019-07-02 00:00:00
# 75%                2020-08-19 00:00:00
# max                2021-09-25 00:00:00
# Name: date_added, dtype: object

# %%
# Convert "release_year" column to datetime format with the middle of the year
df["release_year"] = pd.to_datetime(df["release_year"].astype(str) + '-07-01')
# df["release_year"].head(3)

df["release_year"].describe()
# Out:
# count                             8807
# mean     2014-09-04 23:07:11.247870976
# min                1925-07-01 00:00:00
# 25%                2013-07-01 00:00:00
# 50%                2017-07-01 00:00:00
# 75%                2019-07-01 00:00:00
# max                2021-07-01 00:00:00
# Name: release_year, dtype: object

# %%
df[df["release_year"] == df["release_year"].min()]
# Out:
#      show_id     type                              title director cast  \
# 4250   s4251  TV Show  Pioneers: First Women Filmmakers*      NaN  NaN
#
#      country date_added release_year rating  duration listed_in  \
# 4250     NaN 2018-12-30   1925-07-01  TV-14  1 Season  TV Shows
#
#                                             description
# 4250  This collection restores films from women who ...

# %%
# Create the box plot
plt.figure(figsize=(4, 2))
sns.boxplot(x=df['release_year'])

# Add title and labels
plt.title('Box Plot of Release Year')
plt.xlabel('Release Year')

# Show the plot
plt.show()

# %% [markdown]
# # **1.1 Director**

# %%
# Create a copy of the DataFrame to work on
df_dir = df[["show_id", "title", "director"]].copy()
df_dir[:10]

# Specific check for the title "Scooby-Doo on Zombie Island"
df_dir[df_dir["title"] == "Scooby-Doo on Zombie Island"]
# Out:
#      show_id                        title  \
# 7959   s7960  Scooby-Doo on Zombie Island
#
#                                              director
# 7959  Hiroshi Aoyama, Kazumi Fukushima, Jim Stenstrum

# %%
# Function to replace 'nan' with pd.NA and split director names
def process_director(director):
    if isinstance(director, str) and director == 'nan':
        return [pd.NA]
    elif isinstance(director, str):
        return director.split(', ')
    else:
        return director  # If it's already a list or any other type

df_dir['director'] = df_dir['director'].apply(process_director)
exploded_dir_df = df_dir.explode('director').reset_index(drop=True)
exploded_dir_df[:10]

# Specific check for the title "Scooby-Doo on Zombie Island"
exploded_dir_df[exploded_dir_df['title'] == "Scooby-Doo on Zombie Island"]
# Out:
#      show_id                        title          director
# 8657   s7960  Scooby-Doo on Zombie Island    Hiroshi Aoyama
# 8658   s7960  Scooby-Doo on Zombie Island  Kazumi Fukushima
# 8659   s7960  Scooby-Doo on Zombie Island     Jim Stenstrum

# %% [markdown]
# # **1.2 Cast**

# %%
# Create a copy of the DataFrame to work on
df_cast = df[["show_id", "title", "cast"]].copy()
df_cast[:10]

# Specific check for the title "Blood & Water"
df_cast[df_cast["title"] == "Blood & Water"]
# Out:
#   show_id          title                                               cast
# 1      s2  Blood & Water  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...

# %%
# Function to replace 'nan' with pd.NA and split cast names
def process_cast(cast):
    if isinstance(cast, str) and cast == 'nan':
        return [pd.NA]
    elif isinstance(cast, str):
        return cast.split(', ')
    else:
        return cast  # If it's already a list or any other type

# Assuming df_cast is your DataFrame containing the 'cast' column
df_cast['cast'] = df_cast['cast'].apply(process_cast)
exploded_cast_df = df_cast.explode('cast').reset_index(drop=True)

# Specific check for the title "Blood & Water"
exploded_cast_df[exploded_cast_df['title'] == "Blood & Water"][:10]   #limiting to 10 rows
# Out:
#    show_id          title               cast
# 1       s2  Blood & Water         Ama Qamata
# 2       s2  Blood & Water        Khosi Ngema
# 3       s2  Blood & Water      Gail Mabalane
# 4       s2  Blood & Water     Thabang Molaba
# 5       s2  Blood & Water   Dillon Windvogel
# 6       s2  Blood & Water    Natasha Thahane
# 7       s2  Blood & Water        Arno Greeff
# 8       s2  Blood & Water  Xolile Tshabalala
# 9       s2  Blood & Water    Getmore Sithole
# 10      s2  Blood & Water     Cindy Mahlangu

# %% [markdown]
# # **1.3 Listed in**

# %%
# Create a copy of the DataFrame to work on
df_listed_in = df[["show_id", "title", "listed_in"]].copy()
df_listed_in[:10]

# Specific check for the title "Blood & Water"
df_listed_in[df_listed_in["title"] == "Blood & Water"]
# Out:
#   show_id          title                                        listed_in
# 1      s2  Blood & Water  International TV Shows, TV Dramas, TV Mysteries

# %%
# Function to replace 'nan' with pd.NA and split listed_in entries
def process_listed_in(listed_in):
    if isinstance(listed_in, str) and listed_in == 'nan':
        return [pd.NA]
    elif isinstance(listed_in, str):
        return listed_in.split(', ')
    else:
        return listed_in  # If it's already a list or any other type

# Assuming df_listed_in is your DataFrame containing the 'listed_in' column
df_listed_in['listed_in'] = df_listed_in['listed_in'].apply(process_listed_in)
exploded_listed_in_df = df_listed_in.explode('listed_in').reset_index(drop=True)

# Specific check for the title "Blood & Water"
exploded_listed_in_df[exploded_listed_in_df['title'] == "Blood & Water"]
# Out:
#   show_id          title               listed_in
# 1      s2  Blood & Water  International TV Shows
# 2      s2  Blood & Water               TV Dramas
# 3      s2  Blood & Water            TV Mysteries

# %% [markdown]
# # **1.4 Country**

# %%
# Create a copy of the DataFrame to work on
df_country = df[["show_id", "title", "country"]].copy()
df_country[:10]

# Specific check for the title "Yellowbird"
df_country[df_country["title"] == "Yellowbird"]
# Out:
#      show_id       title          country
# 8776   s8777  Yellowbird  France, Belgium

# %%
# Function to replace 'nan' with pd.NA and split country entries
def process_country(country):
    if isinstance(country, str) and country == 'nan':
        return [pd.NA]
    elif isinstance(country, str):
        return country.split(', ')
    else:
        return country  # If it's already a list or any other type

# Assuming df_country is your DataFrame containing the 'country' column
df_country['country'] = df_country['country'].apply(process_country)
exploded_country_df = df_country.explode('country').reset_index(drop=True)
exploded_country_df
# Specific check for the title "Yellowbird"
exploded_country_df[exploded_country_df['title'] == "Yellowbird"]
# Out:
#       show_id       title  country
# 10802   s8777  Yellowbird   France
# 10803   s8777  Yellowbird  Belgium

# %%
# Define the URL from which to read the CSV file
url = "https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv"
df = pd.read_csv(url)

# Replace 'nan' with pd.NA
# Split strings by comma and convert to list, handling missing values
df['country'] = (df['country']
                  .replace('nan', pd.NA)
                  .apply(lambda x: str(x).split(', ') if pd.notna(x) else [pd.NA])
                  )

# Explode the DataFrame to separate each country into its own row
unnested_country_df = (df[['show_id','title','country']]
                        .explode('country')
                        .reset_index(drop=True)
                        )

# unnested_df now contains each listed-in type in a separate row along with the corresponding title
unnested_country_df.head(15)

### Checks : ok!
unnested_country_df.loc[unnested_country_df['title'] == "You Carry Me"]
# Out:
#       show_id         title     country
# 10817   s8789  You Carry Me     Croatia
# 10818   s8789  You Carry Me    Slovenia
# 10819   s8789  You Carry Me      Serbia
# 10820   s8789  You Carry Me  Montenegro

# %% [markdown]
# # **Merging the Unnested DataFrame**

# %%
# unnested_dir_df
# unnested_cast_df
# unnested_listed_in_df
# unnested_country_df
#-------------------------------------------------------------------------------------

# Merge DataFrames using both 'title' and 'show_id'

merged_df = (unnested_dir_df
             .merge(unnested_cast_df, how='inner', on=['show_id', 'title'])
             .merge(unnested_listed_in_df, how='inner', on=['show_id', 'title'])
             .merge(unnested_country_df, how='inner', on=['show_id', 'title'])
             .merge(df[["show_id",	"type",	"title","date_added",	"release_year",	"rating",	"duration","description"]], how='inner', on=['show_id', 'title'])
             )

# Export merged_df to pickle file
merged_df.to_pickle('merged_df.pkl')

merged_df[:100]
# merged_df.info()
#-------------------------------------------------------------------------------------
# Out:
#    show_id                  title         director                  cast  \
# 0       s1   Dick Johnson Is Dead  Kirsten Johnson                  <NA>
# 1       s2          Blood & Water             <NA>            Ama Qamata
# 2       s2          Blood & Water             <NA>            Ama Qamata
# 3       s2          Blood & Water             <NA>            Ama Qamata
# 4       s2          Blood & Water             <NA>           Khosi Ngema
# 5       s2          Blood & Water             <NA>           Khosi Ngema
# 6       s2          Blood & Water             <NA>           Khosi Ngema
# 7       s2          Blood & Water             <NA>         Gail Mabalane
# 8       s2          Blood & Water             <NA>         Gail Mabalane
# 9       s2          Blood & Water             <NA>         Gail Mabalane
# 10      s2          Blood & Water             <NA>        Thabang Molaba
# 11      s2          Blood & Water             <NA>        Thabang Molaba
# 12      s2          Blood & Water             <NA>        Thabang Molaba
# 13      s2          Blood & Water             <NA>      Dillon Windvogel
# 14      s2          Blood & Water             <NA>      Dillon Windvogel
# 15      s2          Blood & Water             <NA>      Dillon Windvogel
# 16      s2          Blood & Water             <NA>       Natasha Thahane
# 17      s2          Blood & Water             <NA>       Natasha Thahane
# 18      s2          Blood & Water             <NA>       Natasha Thahane
# 19      s2          Blood & Water             <NA>           Arno Greeff
# 20      s2          Blood & Water             <NA>           Arno Greeff
# 21      s2          Blood & Water             <NA>           Arno Greeff
# 22      s2          Blood & Water             <NA>     Xolile Tshabalala
# 23      s2          Blood & Water             <NA>     Xolile Tshabalala
# 24      s2          Blood & Water             <NA>     Xolile Tshabalala
# 25      s2          Blood & Water             <NA>       Getmore Sithole
# 26      s2          Blood & Water             <NA>       Getmore Sithole
# 27      s2          Blood & Water             <NA>       Getmore Sithole
# 28      s2          Blood & Water             <NA>        Cindy Mahlangu
# 29      s2          Blood & Water             <NA>        Cindy Mahlangu
# 30      s2          Blood & Water             <NA>        Cindy Mahlangu
# 31      s2          Blood & Water             <NA>         Ryle De Morny
# 32      s2          Blood & Water             <NA>         Ryle De Morny
# 33      s2          Blood & Water             <NA>         Ryle De Morny
# 34      s2          Blood & Water             <NA>       Greteli Fincham
# 35      s2          Blood & Water             <NA>       Greteli Fincham
# 36      s2          Blood & Water             <NA>       Greteli Fincham
# 37      s2          Blood & Water             <NA>  Sello Maake Ka-Ncube
# 38      s2          Blood & Water             <NA>  Sello Maake Ka-Ncube
# 39      s2          Blood & Water             <NA>  Sello Maake Ka-Ncube
# 40      s2          Blood & Water             <NA>           Odwa Gwanya
# 41      s2          Blood & Water             <NA>           Odwa Gwanya
# 42      s2          Blood & Water             <NA>           Odwa Gwanya
# 43      s2          Blood & Water             <NA>        Mekaila Mathys
# 44      s2          Blood & Water             <NA>        Mekaila Mathys
# 45      s2          Blood & Water             <NA>        Mekaila Mathys
# 46      s2          Blood & Water             <NA>         Sandi Schultz
# 47      s2          Blood & Water             <NA>         Sandi Schultz
# 48      s2          Blood & Water             <NA>         Sandi Schultz
# 49      s2          Blood & Water             <NA>        Duane Williams
# 50      s2          Blood & Water             <NA>        Duane Williams
# 51      s2          Blood & Water             <NA>        Duane Williams
# 52      s2          Blood & Water             <NA>       Shamilla Miller
# 53      s2          Blood & Water             <NA>       Shamilla Miller
# 54      s2          Blood & Water             <NA>       Shamilla Miller
# 55      s2          Blood & Water             <NA>      Patrick Mofokeng
# 56      s2          Blood & Water             <NA>      Patrick Mofokeng
# 57      s2          Blood & Water             <NA>      Patrick Mofokeng
# 58      s3              Ganglands  Julien Leclercq         Sami Bouajila
# 59      s3              Ganglands  Julien Leclercq         Sami Bouajila
# 60      s3              Ganglands  Julien Leclercq         Sami Bouajila
# 61      s3              Ganglands  Julien Leclercq          Tracy Gotoas
# 62      s3              Ganglands  Julien Leclercq          Tracy Gotoas
# 63      s3              Ganglands  Julien Leclercq          Tracy Gotoas
# 64      s3              Ganglands  Julien Leclercq           Samuel Jouy
# 65      s3              Ganglands  Julien Leclercq           Samuel Jouy
# 66      s3              Ganglands  Julien Leclercq           Samuel Jouy
# 67      s3              Ganglands  Julien Leclercq         Nabiha Akkari
# 68      s3              Ganglands  Julien Leclercq         Nabiha Akkari
# 69      s3              Ganglands  Julien Leclercq         Nabiha Akkari
# 70      s3              Ganglands  Julien Leclercq        Sofia Lesaffre
# 71      s3              Ganglands  Julien Leclercq        Sofia Lesaffre
# 72      s3              Ganglands  Julien Leclercq        Sofia Lesaffre
# 73      s3              Ganglands  Julien Leclercq      Salim Kechiouche
# 74      s3              Ganglands  Julien Leclercq      Salim Kechiouche
# 75      s3              Ganglands  Julien Leclercq      Salim Kechiouche
# 76      s3              Ganglands  Julien Leclercq     Noureddine Farihi
# 77      s3              Ganglands  Julien Leclercq     Noureddine Farihi
# 78      s3              Ganglands  Julien Leclercq     Noureddine Farihi
# 79      s3              Ganglands  Julien Leclercq  Geert Van Rampelberg
# 80      s3              Ganglands  Julien Leclercq  Geert Van Rampelberg
# 81      s3              Ganglands  Julien Leclercq  Geert Van Rampelberg
# 82      s3              Ganglands  Julien Leclercq       Bakary Diombera
# 83      s3              Ganglands  Julien Leclercq       Bakary Diombera
# 84      s3              Ganglands  Julien Leclercq       Bakary Diombera
# 85      s4  Jailbirds New Orleans             <NA>                  <NA>
# 86      s4  Jailbirds New Orleans             <NA>                  <NA>
# 87      s5           Kota Factory             <NA>            Mayur More
# 88      s5           Kota Factory             <NA>            Mayur More
# 89      s5           Kota Factory             <NA>            Mayur More
# 90      s5           Kota Factory             <NA>        Jitendra Kumar
# 91      s5           Kota Factory             <NA>        Jitendra Kumar
# 92      s5           Kota Factory             <NA>        Jitendra Kumar
# 93      s5           Kota Factory             <NA>            Ranjan Raj
# 94      s5           Kota Factory             <NA>            Ranjan Raj
# 95      s5           Kota Factory             <NA>            Ranjan Raj
# 96      s5           Kota Factory             <NA>             Alam Khan
# 97      s5           Kota Factory             <NA>             Alam Khan
# 98      s5           Kota Factory             <NA>             Alam Khan
# 99      s5           Kota Factory             <NA>         Ahsaas Channa
#
#                  listed_in        country     type          date_added  \
# 0            Documentaries  United States    Movie  September 25, 2021
# 1   International TV Shows   South Africa  TV Show  September 24, 2021
# 2                TV Dramas   South Africa  TV Show  September 24, 2021
# 3             TV Mysteries   South Africa  TV Show  September 24, 2021
# 4   International TV Shows   South Africa  TV Show  September 24, 2021
# 5                TV Dramas   South Africa  TV Show  September 24, 2021
# 6             TV Mysteries   South Africa  TV Show  September 24, 2021
# 7   International TV Shows   South Africa  TV Show  September 24, 2021
# 8                TV Dramas   South Africa  TV Show  September 24, 2021
# 9             TV Mysteries   South Africa  TV Show  September 24, 2021
# 10  International TV Shows   South Africa  TV Show  September 24, 2021
# 11               TV Dramas   South Africa  TV Show  September 24, 2021
# 12            TV Mysteries   South Africa  TV Show  September 24, 2021
# 13  International TV Shows   South Africa  TV Show  September 24, 2021
# 14               TV Dramas   South Africa  TV Show  September 24, 2021
# 15            TV Mysteries   South Africa  TV Show  September 24, 2021
# 16  International TV Shows   South Africa  TV Show  September 24, 2021
# 17               TV Dramas   South Africa  TV Show  September 24, 2021
# 18            TV Mysteries   South Africa  TV Show  September 24, 2021
# 19  International TV Shows   South Africa  TV Show  September 24, 2021
# 20               TV Dramas   South Africa  TV Show  September 24, 2021
# 21            TV Mysteries   South Africa  TV Show  September 24, 2021
# 22  International TV Shows   South Africa  TV Show  September 24, 2021
# 23               TV Dramas   South Africa  TV Show  September 24, 2021
# 24            TV Mysteries   South Africa  TV Show  September 24, 2021
# 25  International TV Shows   South Africa  TV Show  September 24, 2021
# 26               TV Dramas   South Africa  TV Show  September 24, 2021
# 27            TV Mysteries   South Africa  TV Show  September 24, 2021
# 28  International TV Shows   South Africa  TV Show  September 24, 2021
# 29               TV Dramas   South Africa  TV Show  September 24, 2021
# 30            TV Mysteries   South Africa  TV Show  September 24, 2021
# 31  International TV Shows   South Africa  TV Show  September 24, 2021
# 32               TV Dramas   South Africa  TV Show  September 24, 2021
# 33            TV Mysteries   South Africa  TV Show  September 24, 2021
# 34  International TV Shows   South Africa  TV Show  September 24, 2021
# 35               TV Dramas   South Africa  TV Show  September 24, 2021
# 36            TV Mysteries   South Africa  TV Show  September 24, 2021
# 37  International TV Shows   South Africa  TV Show  September 24, 2021
# 38               TV Dramas   South Africa  TV Show  September 24, 2021
# 39            TV Mysteries   South Africa  TV Show  September 24, 2021
# 40  International TV Shows   South Africa  TV Show  September 24, 2021
# 41               TV Dramas   South Africa  TV Show  September 24, 2021
# 42            TV Mysteries   South Africa  TV Show  September 24, 2021
# 43  International TV Shows   South Africa  TV Show  September 24, 2021
# 44               TV Dramas   South Africa  TV Show  September 24, 2021
# 45            TV Mysteries   South Africa  TV Show  September 24, 2021
# 46  International TV Shows   South Africa  TV Show  September 24, 2021
# 47               TV Dramas   South Africa  TV Show  September 24, 2021
# 48            TV Mysteries   South Africa  TV Show  September 24, 2021
# 49  International TV Shows   South Africa  TV Show  September 24, 2021
# 50               TV Dramas   South Africa  TV Show  September 24, 2021
# 51            TV Mysteries   South Africa  TV Show  September 24, 2021
# 52  International TV Shows   South Africa  TV Show  September 24, 2021
# 53               TV Dramas   South Africa  TV Show  September 24, 2021
# 54            TV Mysteries   South Africa  TV Show  September 24, 2021
# 55  International TV Shows   South Africa  TV Show  September 24, 2021
# 56               TV Dramas   South Africa  TV Show  September 24, 2021
# 57            TV Mysteries   South Africa  TV Show  September 24, 2021
# 58          Crime TV Shows           <NA>  TV Show  September 24, 2021
# 59  International TV Shows           <NA>  TV Show  September 24, 2021
# 60   TV Action & Adventure           <NA>  TV Show  September 24, 2021
# 61          Crime TV Shows           <NA>  TV Show  September 24, 2021
# 62  International TV Shows           <NA>  TV Show  September 24, 2021
# 63   TV Action & Adventure           <NA>  TV Show  September 24, 2021
# 64          Crime TV Shows           <NA>  TV Show  September 24, 2021
# 65  International TV Shows           <NA>  TV Show  September 24, 2021
# 66   TV Action & Adventure           <NA>  TV Show  September 24, 2021
# 67          Crime TV Shows           <NA>  TV Show  September 24, 2021
# 68  International TV Shows           <NA>  TV Show  September 24, 2021
# 69   TV Action & Adventure           <NA>  TV Show  September 24, 2021
# 70          Crime TV Shows           <NA>  TV Show  September 24, 2021
# 71  International TV Shows           <NA>  TV Show  September 24, 2021
# 72   TV Action & Adventure           <NA>  TV Show  September 24, 2021
# 73          Crime TV Shows           <NA>  TV Show  September 24, 2021
# 74  International TV Shows           <NA>  TV Show  September 24, 2021
# 75   TV Action & Adventure           <NA>  TV Show  September 24, 2021
# 76          Crime TV Shows           <NA>  TV Show  September 24, 2021
# 77  International TV Shows           <NA>  TV Show  September 24, 2021
# 78   TV Action & Adventure           <NA>  TV Show  September 24, 2021
# 79          Crime TV Shows           <NA>  TV Show  September 24, 2021
# 80  International TV Shows           <NA>  TV Show  September 24, 2021
# 81   TV Action & Adventure           <NA>  TV Show  September 24, 2021
# 82          Crime TV Shows           <NA>  TV Show  September 24, 2021
# 83  International TV Shows           <NA>  TV Show  September 24, 2021
# 84   TV Action & Adventure           <NA>  TV Show  September 24, 2021
# 85              Docuseries           <NA>  TV Show  September 24, 2021
# 86              Reality TV           <NA>  TV Show  September 24, 2021
# 87  International TV Shows          India  TV Show  September 24, 2021
# 88       Romantic TV Shows          India  TV Show  September 24, 2021
# 89             TV Comedies          India  TV Show  September 24, 2021
# 90  International TV Shows          India  TV Show  September 24, 2021
# 91       Romantic TV Shows          India  TV Show  September 24, 2021
# 92             TV Comedies          India  TV Show  September 24, 2021
# 93  International TV Shows          India  TV Show  September 24, 2021
# 94       Romantic TV Shows          India  TV Show  September 24, 2021
# 95             TV Comedies          India  TV Show  September 24, 2021
# 96  International TV Shows          India  TV Show  September 24, 2021
# 97       Romantic TV Shows          India  TV Show  September 24, 2021
# 98             TV Comedies          India  TV Show  September 24, 2021
# 99  International TV Shows          India  TV Show  September 24, 2021
#
#     release_year rating   duration  \
# 0           2020  PG-13     90 min
# 1           2021  TV-MA  2 Seasons
# 2           2021  TV-MA  2 Seasons
# 3           2021  TV-MA  2 Seasons
# 4           2021  TV-MA  2 Seasons
# 5           2021  TV-MA  2 Seasons
# 6           2021  TV-MA  2 Seasons
# 7           2021  TV-MA  2 Seasons
# 8           2021  TV-MA  2 Seasons
# 9           2021  TV-MA  2 Seasons
# 10          2021  TV-MA  2 Seasons
# 11          2021  TV-MA  2 Seasons
# 12          2021  TV-MA  2 Seasons
# 13          2021  TV-MA  2 Seasons
# 14          2021  TV-MA  2 Seasons
# 15          2021  TV-MA  2 Seasons
# 16          2021  TV-MA  2 Seasons
# 17          2021  TV-MA  2 Seasons
# 18          2021  TV-MA  2 Seasons
# 19          2021  TV-MA  2 Seasons
# 20          2021  TV-MA  2 Seasons
# 21          2021  TV-MA  2 Seasons
# 22          2021  TV-MA  2 Seasons
# 23          2021  TV-MA  2 Seasons
# 24          2021  TV-MA  2 Seasons
# 25          2021  TV-MA  2 Seasons
# 26          2021  TV-MA  2 Seasons
# 27          2021  TV-MA  2 Seasons
# 28          2021  TV-MA  2 Seasons
# 29          2021  TV-MA  2 Seasons
# 30          2021  TV-MA  2 Seasons
# 31          2021  TV-MA  2 Seasons
# 32          2021  TV-MA  2 Seasons
# 33          2021  TV-MA  2 Seasons
# 34          2021  TV-MA  2 Seasons
# 35          2021  TV-MA  2 Seasons
# 36          2021  TV-MA  2 Seasons
# 37          2021  TV-MA  2 Seasons
# 38          2021  TV-MA  2 Seasons
# 39          2021  TV-MA  2 Seasons
# 40          2021  TV-MA  2 Seasons
# 41          2021  TV-MA  2 Seasons
# 42          2021  TV-MA  2 Seasons
# 43          2021  TV-MA  2 Seasons
# 44          2021  TV-MA  2 Seasons
# 45          2021  TV-MA  2 Seasons
# 46          2021  TV-MA  2 Seasons
# 47          2021  TV-MA  2 Seasons
# 48          2021  TV-MA  2 Seasons
# 49          2021  TV-MA  2 Seasons
# 50          2021  TV-MA  2 Seasons
# 51          2021  TV-MA  2 Seasons
# 52          2021  TV-MA  2 Seasons
# 53          2021  TV-MA  2 Seasons
# 54          2021  TV-MA  2 Seasons
# 55          2021  TV-MA  2 Seasons
# 56          2021  TV-MA  2 Seasons
# 57          2021  TV-MA  2 Seasons
# 58          2021  TV-MA   1 Season
# 59          2021  TV-MA   1 Season
# 60          2021  TV-MA   1 Season
# 61          2021  TV-MA   1 Season
# 62          2021  TV-MA   1 Season
# 63          2021  TV-MA   1 Season
# 64          2021  TV-MA   1 Season
# 65          2021  TV-MA   1 Season
# 66          2021  TV-MA   1 Season
# 67          2021  TV-MA   1 Season
# 68          2021  TV-MA   1 Season
# 69          2021  TV-MA   1 Season
# 70          2021  TV-MA   1 Season
# 71          2021  TV-MA   1 Season
# 72          2021  TV-MA   1 Season
# 73          2021  TV-MA   1 Season
# 74          2021  TV-MA   1 Season
# 75          2021  TV-MA   1 Season
# 76          2021  TV-MA   1 Season
# 77          2021  TV-MA   1 Season
# 78          2021  TV-MA   1 Season
# 79          2021  TV-MA   1 Season
# 80          2021  TV-MA   1 Season
# 81          2021  TV-MA   1 Season
# 82          2021  TV-MA   1 Season
# 83          2021  TV-MA   1 Season
# 84          2021  TV-MA   1 Season
# 85          2021  TV-MA   1 Season
# 86          2021  TV-MA   1 Season
# 87          2021  TV-MA  2 Seasons
# 88          2021  TV-MA  2 Seasons
# 89          2021  TV-MA  2 Seasons
# 90          2021  TV-MA  2 Seasons
# 91          2021  TV-MA  2 Seasons
# 92          2021  TV-MA  2 Seasons
# 93          2021  TV-MA  2 Seasons
# 94          2021  TV-MA  2 Seasons
# 95          2021  TV-MA  2 Seasons
# 96          2021  TV-MA  2 Seasons
# 97          2021  TV-MA  2 Seasons
# 98          2021  TV-MA  2 Seasons
# 99          2021  TV-MA  2 Seasons
#
#                                           description
# 0   As her father nears the end of his life, filmm...
# 1   After crossing paths at a party, a Cape Town t...
# 2   After crossing paths at a party, a Cape Town t...
# 3   After crossing paths at a party, a Cape Town t...
# 4   After crossing paths at a party, a Cape Town t...
# 5   After crossing paths at a party, a Cape Town t...
# 6   After crossing paths at a party, a Cape Town t...
# 7   After crossing paths at a party, a Cape Town t...
# 8   After crossing paths at a party, a Cape Town t...
# 9   After crossing paths at a party, a Cape Town t...
# 10  After crossing paths at a party, a Cape Town t...
# 11  After crossing paths at a party, a Cape Town t...
# 12  After crossing paths at a party, a Cape Town t...
# 13  After crossing paths at a party, a Cape Town t...
# 14  After crossing paths at a party, a Cape Town t...
# 15  After crossing paths at a party, a Cape Town t...
# 16  After crossing paths at a party, a Cape Town t...
# 17  After crossing paths at a party, a Cape Town t...
# 18  After crossing paths at a party, a Cape Town t...
# 19  After crossing paths at a party, a Cape Town t...
# 20  After crossing paths at a party, a Cape Town t...
# 21  After crossing paths at a party, a Cape Town t...
# 22  After crossing paths at a party, a Cape Town t...
# 23  After crossing paths at a party, a Cape Town t...
# 24  After crossing paths at a party, a Cape Town t...
# 25  After crossing paths at a party, a Cape Town t...
# 26  After crossing paths at a party, a Cape Town t...
# 27  After crossing paths at a party, a Cape Town t...
# 28  After crossing paths at a party, a Cape Town t...
# 29  After crossing paths at a party, a Cape Town t...
# 30  After crossing paths at a party, a Cape Town t...
# 31  After crossing paths at a party, a Cape Town t...
# 32  After crossing paths at a party, a Cape Town t...
# 33  After crossing paths at a party, a Cape Town t...
# 34  After crossing paths at a party, a Cape Town t...
# 35  After crossing paths at a party, a Cape Town t...
# 36  After crossing paths at a party, a Cape Town t...
# 37  After crossing paths at a party, a Cape Town t...
# 38  After crossing paths at a party, a Cape Town t...
# 39  After crossing paths at a party, a Cape Town t...
# 40  After crossing paths at a party, a Cape Town t...
# 41  After crossing paths at a party, a Cape Town t...
# 42  After crossing paths at a party, a Cape Town t...
# 43  After crossing paths at a party, a Cape Town t...
# 44  After crossing paths at a party, a Cape Town t...
# 45  After crossing paths at a party, a Cape Town t...
# 46  After crossing paths at a party, a Cape Town t...
# 47  After crossing paths at a party, a Cape Town t...
# 48  After crossing paths at a party, a Cape Town t...
# 49  After crossing paths at a party, a Cape Town t...
# 50  After crossing paths at a party, a Cape Town t...
# 51  After crossing paths at a party, a Cape Town t...
# 52  After crossing paths at a party, a Cape Town t...
# 53  After crossing paths at a party, a Cape Town t...
# 54  After crossing paths at a party, a Cape Town t...
# 55  After crossing paths at a party, a Cape Town t...
# 56  After crossing paths at a party, a Cape Town t...
# 57  After crossing paths at a party, a Cape Town t...
# 58  To protect his family from a powerful drug lor...
# 59  To protect his family from a powerful drug lor...
# 60  To protect his family from a powerful drug lor...
# 61  To protect his family from a powerful drug lor...
# 62  To protect his family from a powerful drug lor...
# 63  To protect his family from a powerful drug lor...
# 64  To protect his family from a powerful drug lor...
# 65  To protect his family from a powerful drug lor...
# 66  To protect his family from a powerful drug lor...
# 67  To protect his family from a powerful drug lor...
# 68  To protect his family from a powerful drug lor...
# 69  To protect his family from a powerful drug lor...
# 70  To protect his family from a powerful drug lor...
# 71  To protect his family from a powerful drug lor...
# 72  To protect his family from a powerful drug lor...
# 73  To protect his family from a powerful drug lor...
# 74  To protect his family from a powerful drug lor...
# 75  To protect his family from a powerful drug lor...
# 76  To protect his family from a powerful drug lor...
# 77  To protect his family from a powerful drug lor...
# 78  To protect his family from a powerful drug lor...
# 79  To protect his family from a powerful drug lor...
# 80  To protect his family from a powerful drug lor...
# 81  To protect his family from a powerful drug lor...
# 82  To protect his family from a powerful drug lor...
# 83  To protect his family from a powerful drug lor...
# 84  To protect his family from a powerful drug lor...
# 85  Feuds, flirtations and toilet talk go down amo...
# 86  Feuds, flirtations and toilet talk go down amo...
# 87  In a city of coaching centers known to train I...
# 88  In a city of coaching centers known to train I...
# 89  In a city of coaching centers known to train I...
# 90  In a city of coaching centers known to train I...
# 91  In a city of coaching centers known to train I...
# 92  In a city of coaching centers known to train I...
# 93  In a city of coaching centers known to train I...
# 94  In a city of coaching centers known to train I...
# 95  In a city of coaching centers known to train I...
# 96  In a city of coaching centers known to train I...
# 97  In a city of coaching centers known to train I...
# 98  In a city of coaching centers known to train I...
# 99  In a city of coaching centers known to train I...

# %%
# Import merged_df from pickle file
df_imported = pd.read_pickle('merged_df.pkl')


data_quality_statistics(df_imported)

# Now lets think how to immute the missing values Logically

#
# Out:
#           Column  Number of Rows  Number of Unique Values  Number of NaN  \
# 0        show_id          201991                     8807              0
# 1          title          201991                     8807              0
# 2       director          201991                     4993          50643
# 3           cast          201991                    36439           2146
# 4      listed_in          201991                       42              0
# 5        country          201991                      127          11897
# 6           type          201991                        2              0
# 7     date_added          201991                     1767            158
# 8   release_year          201991                       74              0
# 9         rating          201991                       17             67
# 10      duration          201991                      220              3
# 11   description          201991                     8775              0
#
#     Percentage of NaN Data Type
# 0                0.00    object
# 1                0.00    object
# 2               25.07    object
# 3                1.06    object
# 4                0.00    object
# 5                5.89    object
# 6                0.00    object
# 7                0.08    object
# 8                0.00     int64
# 9                0.03    object
# 10               0.00    object
# 11               0.00    object

# %%
import pandas as pd

director_mapping_data = df_imported[['director', 'cast', 'listed_in', 'country', 'type']].copy()

director_mapping_data.dropna(subset=['director', 'cast', 'listed_in', 'country', 'type'], inplace=True)

director_mapping_data.drop_duplicates(inplace=True)

director_mapping_data[:100]
# Out:
#          director                 cast             listed_in         country  \
# 179  Haile Gerima         Kofi Ghanaba                Dramas   United States
# 180  Haile Gerima         Kofi Ghanaba                Dramas           Ghana
# 181  Haile Gerima         Kofi Ghanaba                Dramas    Burkina Faso
# 182  Haile Gerima         Kofi Ghanaba                Dramas  United Kingdom
# 183  Haile Gerima         Kofi Ghanaba                Dramas         Germany
# 184  Haile Gerima         Kofi Ghanaba                Dramas        Ethiopia
# 185  Haile Gerima         Kofi Ghanaba    Independent Movies   United States
# 186  Haile Gerima         Kofi Ghanaba    Independent Movies           Ghana
# 187  Haile Gerima         Kofi Ghanaba    Independent Movies    Burkina Faso
# 188  Haile Gerima         Kofi Ghanaba    Independent Movies  United Kingdom
# 189  Haile Gerima         Kofi Ghanaba    Independent Movies         Germany
# 190  Haile Gerima         Kofi Ghanaba    Independent Movies        Ethiopia
# 191  Haile Gerima         Kofi Ghanaba  International Movies   United States
# 192  Haile Gerima         Kofi Ghanaba  International Movies           Ghana
# 193  Haile Gerima         Kofi Ghanaba  International Movies    Burkina Faso
# 194  Haile Gerima         Kofi Ghanaba  International Movies  United Kingdom
# 195  Haile Gerima         Kofi Ghanaba  International Movies         Germany
# 196  Haile Gerima         Kofi Ghanaba  International Movies        Ethiopia
# 197  Haile Gerima  Oyafunmike Ogunlano                Dramas   United States
# 198  Haile Gerima  Oyafunmike Ogunlano                Dramas           Ghana
# 199  Haile Gerima  Oyafunmike Ogunlano                Dramas    Burkina Faso
# 200  Haile Gerima  Oyafunmike Ogunlano                Dramas  United Kingdom
# 201  Haile Gerima  Oyafunmike Ogunlano                Dramas         Germany
# 202  Haile Gerima  Oyafunmike Ogunlano                Dramas        Ethiopia
# 203  Haile Gerima  Oyafunmike Ogunlano    Independent Movies   United States
# 204  Haile Gerima  Oyafunmike Ogunlano    Independent Movies           Ghana
# 205  Haile Gerima  Oyafunmike Ogunlano    Independent Movies    Burkina Faso
# 206  Haile Gerima  Oyafunmike Ogunlano    Independent Movies  United Kingdom
# 207  Haile Gerima  Oyafunmike Ogunlano    Independent Movies         Germany
# 208  Haile Gerima  Oyafunmike Ogunlano    Independent Movies        Ethiopia
# 209  Haile Gerima  Oyafunmike Ogunlano  International Movies   United States
# 210  Haile Gerima  Oyafunmike Ogunlano  International Movies           Ghana
# 211  Haile Gerima  Oyafunmike Ogunlano  International Movies    Burkina Faso
# 212  Haile Gerima  Oyafunmike Ogunlano  International Movies  United Kingdom
# 213  Haile Gerima  Oyafunmike Ogunlano  International Movies         Germany
# 214  Haile Gerima  Oyafunmike Ogunlano  International Movies        Ethiopia
# 215  Haile Gerima       Alexandra Duah                Dramas   United States
# 216  Haile Gerima       Alexandra Duah                Dramas           Ghana
# 217  Haile Gerima       Alexandra Duah                Dramas    Burkina Faso
# 218  Haile Gerima       Alexandra Duah                Dramas  United Kingdom
# 219  Haile Gerima       Alexandra Duah                Dramas         Germany
# 220  Haile Gerima       Alexandra Duah                Dramas        Ethiopia
# 221  Haile Gerima       Alexandra Duah    Independent Movies   United States
# 222  Haile Gerima       Alexandra Duah    Independent Movies           Ghana
# 223  Haile Gerima       Alexandra Duah    Independent Movies    Burkina Faso
# 224  Haile Gerima       Alexandra Duah    Independent Movies  United Kingdom
# 225  Haile Gerima       Alexandra Duah    Independent Movies         Germany
# 226  Haile Gerima       Alexandra Duah    Independent Movies        Ethiopia
# 227  Haile Gerima       Alexandra Duah  International Movies   United States
# 228  Haile Gerima       Alexandra Duah  International Movies           Ghana
# 229  Haile Gerima       Alexandra Duah  International Movies    Burkina Faso
# 230  Haile Gerima       Alexandra Duah  International Movies  United Kingdom
# 231  Haile Gerima       Alexandra Duah  International Movies         Germany
# 232  Haile Gerima       Alexandra Duah  International Movies        Ethiopia
# 233  Haile Gerima          Nick Medley                Dramas   United States
# 234  Haile Gerima          Nick Medley                Dramas           Ghana
# 235  Haile Gerima          Nick Medley                Dramas    Burkina Faso
# 236  Haile Gerima          Nick Medley                Dramas  United Kingdom
# 237  Haile Gerima          Nick Medley                Dramas         Germany
# 238  Haile Gerima          Nick Medley                Dramas        Ethiopia
# 239  Haile Gerima          Nick Medley    Independent Movies   United States
# 240  Haile Gerima          Nick Medley    Independent Movies           Ghana
# 241  Haile Gerima          Nick Medley    Independent Movies    Burkina Faso
# 242  Haile Gerima          Nick Medley    Independent Movies  United Kingdom
# 243  Haile Gerima          Nick Medley    Independent Movies         Germany
# 244  Haile Gerima          Nick Medley    Independent Movies        Ethiopia
# 245  Haile Gerima          Nick Medley  International Movies   United States
# 246  Haile Gerima          Nick Medley  International Movies           Ghana
# 247  Haile Gerima          Nick Medley  International Movies    Burkina Faso
# 248  Haile Gerima          Nick Medley  International Movies  United Kingdom
# 249  Haile Gerima          Nick Medley  International Movies         Germany
# 250  Haile Gerima          Nick Medley  International Movies        Ethiopia
# 251  Haile Gerima           Mutabaruka                Dramas   United States
# 252  Haile Gerima           Mutabaruka                Dramas           Ghana
# 253  Haile Gerima           Mutabaruka                Dramas    Burkina Faso
# 254  Haile Gerima           Mutabaruka                Dramas  United Kingdom
# 255  Haile Gerima           Mutabaruka                Dramas         Germany
# 256  Haile Gerima           Mutabaruka                Dramas        Ethiopia
# 257  Haile Gerima           Mutabaruka    Independent Movies   United States
# 258  Haile Gerima           Mutabaruka    Independent Movies           Ghana
# 259  Haile Gerima           Mutabaruka    Independent Movies    Burkina Faso
# 260  Haile Gerima           Mutabaruka    Independent Movies  United Kingdom
# 261  Haile Gerima           Mutabaruka    Independent Movies         Germany
# 262  Haile Gerima           Mutabaruka    Independent Movies        Ethiopia
# 263  Haile Gerima           Mutabaruka  International Movies   United States
# 264  Haile Gerima           Mutabaruka  International Movies           Ghana
# 265  Haile Gerima           Mutabaruka  International Movies    Burkina Faso
# 266  Haile Gerima           Mutabaruka  International Movies  United Kingdom
# 267  Haile Gerima           Mutabaruka  International Movies         Germany
# 268  Haile Gerima           Mutabaruka  International Movies        Ethiopia
# 269  Haile Gerima        Afemo Omilami                Dramas   United States
# 270  Haile Gerima        Afemo Omilami                Dramas           Ghana
# 271  Haile Gerima        Afemo Omilami                Dramas    Burkina Faso
# 272  Haile Gerima        Afemo Omilami                Dramas  United Kingdom
# 273  Haile Gerima        Afemo Omilami                Dramas         Germany
# 274  Haile Gerima        Afemo Omilami                Dramas        Ethiopia
# 275  Haile Gerima        Afemo Omilami    Independent Movies   United States
# 276  Haile Gerima        Afemo Omilami    Independent Movies           Ghana
# 277  Haile Gerima        Afemo Omilami    Independent Movies    Burkina Faso
# 278  Haile Gerima        Afemo Omilami    Independent Movies  United Kingdom
#
#       type
# 179  Movie
# 180  Movie
# 181  Movie
# 182  Movie
# 183  Movie
# 184  Movie
# 185  Movie
# 186  Movie
# 187  Movie
# 188  Movie
# 189  Movie
# 190  Movie
# 191  Movie
# 192  Movie
# 193  Movie
# 194  Movie
# 195  Movie
# 196  Movie
# 197  Movie
# 198  Movie
# 199  Movie
# 200  Movie
# 201  Movie
# 202  Movie
# 203  Movie
# 204  Movie
# 205  Movie
# 206  Movie
# 207  Movie
# 208  Movie
# 209  Movie
# 210  Movie
# 211  Movie
# 212  Movie
# 213  Movie
# 214  Movie
# 215  Movie
# 216  Movie
# 217  Movie
# 218  Movie
# 219  Movie
# 220  Movie
# 221  Movie
# 222  Movie
# 223  Movie
# 224  Movie
# 225  Movie
# 226  Movie
# 227  Movie
# 228  Movie
# 229  Movie
# 230  Movie
# 231  Movie
# 232  Movie
# 233  Movie
# 234  Movie
# 235  Movie
# 236  Movie
# 237  Movie
# 238  Movie
# 239  Movie
# 240  Movie
# 241  Movie
# 242  Movie
# 243  Movie
# 244  Movie
# 245  Movie
# 246  Movie
# 247  Movie
# 248  Movie
# 249  Movie
# 250  Movie
# 251  Movie
# 252  Movie
# 253  Movie
# 254  Movie
# 255  Movie
# 256  Movie
# 257  Movie
# 258  Movie
# 259  Movie
# 260  Movie
# 261  Movie
# 262  Movie
# 263  Movie
# 264  Movie
# 265  Movie
# 266  Movie
# 267  Movie
# 268  Movie
# 269  Movie
# 270  Movie
# 271  Movie
# 272  Movie
# 273  Movie
# 274  Movie
# 275  Movie
# 276  Movie
# 277  Movie
# 278  Movie

# %%
import pandas as pd

# Assuming df_imported and director_mapping_data are your DataFrames

# Calculate mode director for each combination of 'listed_in', 'country', and 'type'
mode_directors = director_mapping_data.groupby(['listed_in', 'country', 'type'])['director'].apply(lambda x: x.mode().iloc[0])

# Merge mode directors back to df_imported
df_imported['director_imputed'] = df_imported.merge(mode_directors, on=['listed_in', 'country', 'type'], how='left')['director_y']

# Fill missing director values with mode imputed values
df_imported['director_imputed'] = df_imported['director_imputed'].fillna(df_imported['director'])

# Drop unnecessary columns
df_imported.drop(['director'], axis=1, inplace=True)

# Rename director_imputed column to director
df_imported.rename(columns={'director_imputed': 'director'}, inplace=True)

# Display df_imported with imputed director values
df_imported[:100]

data_quality_statistics(df_imported)
# Out:
#           Column  Number of Rows  Number of Unique Values  Number of NaN  \
# 0        show_id          201991                     8807              0
# 1          title          201991                     8807              0
# 2           cast          201991                    36439           2146
# 3      listed_in          201991                       42              0
# 4        country          201991                      127          11897
# 5           type          201991                        2              0
# 6     date_added          201991                     1767            158
# 7   release_year          201991                       74              0
# 8         rating          201991                       17             67
# 9       duration          201991                      220              3
# 10   description          201991                     8775              0
# 11      director          201991                      982          12999
#
#     Percentage of NaN Data Type
# 0                0.00    object
# 1                0.00    object
# 2                1.06    object
# 3                0.00    object
# 4                5.89    object
# 5                0.00    object
# 6                0.08    object
# 7                0.00     int64
# 8                0.03    object
# 9                0.00    object
# 10               0.00    object
# 11               6.44    object

# %%
import pandas as pd

# Assuming df_imported and director_mapping_data are your DataFrames

# Calculate mode country for each combination of 'director', 'cast', 'listed_in', and 'type'
mode_countries = director_mapping_data.groupby(['director', 'cast', 'listed_in', 'type'])['country'].apply(lambda x: x.mode().iloc[0])

# Merge mode countries back to df_imported
df_imported['country_imputed'] = df_imported.merge(mode_countries, on=['director', 'cast', 'listed_in', 'type'], how='left')['country_y']

# Fill missing country values with mode imputed values
df_imported['country_imputed'] = df_imported['country_imputed'].fillna(df_imported['country'])

# Drop unnecessary columns
df_imported.drop(['country'], axis=1, inplace=True)

# Rename country_imputed column to country
df_imported.rename(columns={'country_imputed': 'country'}, inplace=True)

# Display df_imported with imputed country values
df_imported

data_quality_statistics(df_imported)
# Out:
#           Column  Number of Rows  Number of Unique Values  Number of NaN  \
# 0        show_id          201991                     8807              0
# 1          title          201991                     8807              0
# 2           cast          201991                    36439           2146
# 3      listed_in          201991                       42              0
# 4           type          201991                        2              0
# 5     date_added          201991                     1767            158
# 6   release_year          201991                       74              0
# 7         rating          201991                       17             67
# 8       duration          201991                      220              3
# 9    description          201991                     8775              0
# 10      director          201991                      982          12999
# 11       country          201991                      113          11183
#
#     Percentage of NaN Data Type
# 0                0.00    object
# 1                0.00    object
# 2                1.06    object
# 3                0.00    object
# 4                0.00    object
# 5                0.08    object
# 6                0.00     int64
# 7                0.03    object
# 8                0.00    object
# 9                0.00    object
# 10               6.44    object
# 11               5.54    object

# %%
missing_values = df_imported.isnull()
tidy = df.loc[~missing_values.any(axis=1)]
miss = df.loc[missing_values.any(axis=1)]

# %%
# Filter the DataFrame to select rows with missing values in specified columns
filtered_df = df_imported[df_imported['director'].isna()
                          # | df_imported['cast'].isna()
                          # | df_imported['title'].isna()
                          | df_imported['country'].isna()
                          # | df_imported['listed_in'].isna()
                          ]

# Select the first 1000 rows from the filtered DataFrame
filtered_df[:1000]

# Save the filtered DataFrame to a CSV file
filtered_df.to_csv('missing_values.csv', index=False)

# %% [markdown]
# # **ABC**

# %%
data_quality_statistics(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-141-b548f10172d1> in <cell line: 1>()
# ----> 1 data_quality_statistics(df)
#
# <ipython-input-125-2d1820bbf84e> in data_quality_statistics(df)
#      22     for col in df.columns:
#      23         # Number of unique values
# ---> 24         num_unique = df[col].nunique()
#      25
#      26         # Number of NaN values
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in nunique(self, dropna)
#    1066         4
#    1067         """
# -> 1068         uniqs = self.unique()
#    1069         if dropna:
#    1070             uniqs = remove_na_arraylike(uniqs)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in unique(self)
#    2192         Categories (3, object): ['a' < 'b' < 'c']
#    2193         """
# -> 2194         return super().unique()
#    2195
#    2196     @overload
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in unique(self)
#    1028             result = values.unique()
#    1029         else:
# -> 1030             result = algorithms.unique1d(values)
#    1031         return result
#    1032
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in unique(values)
#     388     array([('a', 'b'), ('b', 'a'), ('a', 'c')], dtype=object)
#     389     """
# --> 390     return unique_with_mask(values)
#     391
#     392
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in unique_with_mask(values, mask)
#     427     table = hashtable(len(values))
#     428     if mask is None:
# --> 429         uniques = table.unique(values)
#     430         uniques = _reconstruct_data(uniques, original.dtype, original)
#     431         return uniques
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
missing_values = df.isnull()
tidy = df.loc[~missing_values.any(axis=1)]
miss = df.loc[missing_values.any(axis=1)]

# %%
tidy.shape

# %%
miss.shape

# %%
missing_values = df.isnull()
tidy = df.loc[~missing_values.any(axis=1)]
miss = df.loc[missing_values.any(axis=1)]

print(tidy.shape[0]) # No NaN in any Rows
print(miss.shape[0]) # At least 1 NaN in all Rows

# %%
data_quality_statistics(miss)

# %%
# from the above "data_quality_statistics" we can obsere there are 225 unique coutries, which is leading to suspison.

url = "https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv"
df = pd.read_csv(url)

df["country"].unique()[:100] #..Code(1)
# df["country"].value_counts() #..Code(2)

# we can see issues like
      # nan
      # 'United States' , 'United States, and United States'
      # Extra whitespace
      #  Some entries have multiple countries listed together separated by commas, example "Mexico, United States, Spain, Colombia" , "France, Senegal, Belgium" etc

# %%
import pandas as pd

url = "https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv"
df = pd.read_csv(url)

df["country"] = df["country"].fillna("").astype(str)
a=sorted(df["country"].unique())[:100]
print(len(df['country'].unique()))
# Split entries with multiple countries into separate rows
df['country'] = df['country'].str.split(', ')
df = df.explode('country')

# Clean up country names
# The 'explode' function splits entries with multiple countries into separate rows.
# For example, if a row originally had 'United States, Canada', it would become two rows,
# one with 'United States' and another with 'Canada'.
# The 'split' function splits the string on commas, creating a list of countries.
# Then, 'explode' converts each item in the list into a separate row.
# This is necessary because each row should represent only one country.

# The following lines would strip leading and trailing whitespaces from country names.
# However, it seems that the data already has clean country names, so this step is unnecessary.
# df['country'] = df['country'].str.strip()

# Now, let's get the unique country names
# print(len(df['country'].unique()))

# df["country"] = df["country"].fillna("").astype(str)
# sorted(df["country"].unique())[:100]
# df["country"].value_counts() #..Code(2)\
# df["country"].isna()
a[:10]

# %%
df.show_id.nunique()

# %%
# Country Specific Type --->
# Country Specific Listed-in (Genre) --->
# Evolution of kind of Movies/TV Series Change ---> rank fo each movie/tv-series change w.r.t release_year --->
# Evolution of duration of Movies Series Change --->
# In which month the movies are released, and it going well ---> Trend Analysis. --->
# Most Casted Actor   --->
# Productive Director --->  no, of movies/ range of timeframe
#
Cast = Actor

# %%
url = "https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv"
df = pd.read_csv(url)


mask = (df["director"].isna() & df["country"].isna())
df[mask].shape
# Out:
# (409, 12)

# %%
mask = (df["cast"].isna() & df["country"].isna())
df[mask].shape
# Out:
# (154, 12)

# %%
mask = (df["cast"].isna() & df["director"].isna() & df["country"].isna())
df[mask].shape

# observation 96 rows have - unfillable rows
# Out:
# (96, 12)

# %%
96/8807*100
# Out:
# 1.0900420120358805

# %%
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object

df['director'] = (df['director']
                  .replace('nan', pd.NA)
                  .apply(lambda x: str(x).split(', ') if pd.notna(x) else [pd.NA])
                  )

# Explode the DataFrame to separate each director into its own row
unnested_dir_df = (df[["show_id","title","director"]]
                   .explode('director')
                   .reset_index(drop=True)
                   )

# %%
url = "https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv"
df = pd.read_csv(url)

mask = (df["cast"].isna()
          & df["director"].isna()
          & df["country"].isna()
          & df["listed_in"].isna())

df[mask].shape


# observation 0 rows have
# Out:
# (0, 12)

# %%
url = "https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv"
df = pd.read_csv(url)

df['listed_in'] = (df['listed_in']
                  .replace('nan', pd.NA)
                  .apply(lambda x: str(x).split(', ') if pd.notna(x) else [pd.NA])
                  )

newdf=df[["director","listed_in","country"]][df["director"].isna()]

newdf.explode("listed_in")[:20]
# Out:
#    director                  listed_in        country
# 1       NaN     International TV Shows   South Africa
# 1       NaN                  TV Dramas   South Africa
# 1       NaN               TV Mysteries   South Africa
# 3       NaN                 Docuseries            NaN
# 3       NaN                 Reality TV            NaN
# 4       NaN     International TV Shows          India
# 4       NaN          Romantic TV Shows          India
# 4       NaN                TV Comedies          India
# 10      NaN             Crime TV Shows            NaN
# 10      NaN                 Docuseries            NaN
# 10      NaN     International TV Shows            NaN
# 14      NaN           British TV Shows            NaN
# 14      NaN             Crime TV Shows            NaN
# 14      NaN                 Docuseries            NaN
# 15      NaN                TV Comedies  United States
# 15      NaN                  TV Dramas  United States
# 17      NaN             Crime TV Shows         Mexico
# 17      NaN  Spanish-Language TV Shows         Mexico
# 17      NaN                  TV Dramas         Mexico
# 19      NaN     International TV Shows            NaN

# %%
url = "https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv"
df = pd.read_csv(url)

df['listed_in'] = (df['listed_in']
                  .replace('nan', pd.NA)
                  .apply(lambda x: str(x).split(', ') if pd.notna(x) else [pd.NA])
                  )

comb_df = (df[["show_id","director","country","listed_in"]]
                   .explode('listed_in')
                   .reset_index(drop=True)
                   )
# Romantic TV Shows	India
# 8740	NaN	British TV Shows	United Kingdom
mask2 = ((comb_df["listed_in"] == "Romantic TV") & (comb_df["country"] == "India") & (~comb_df["director"].isna()))
comb_df[mask2].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
# checking that "NAN" 96 rows


url = "https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv"
df = pd.read_csv(url)

mask3 = (df["cast"].isna() & df["director"].isna() & df["country"].isna())
df[mask3][:5]


# df[mask3].shape
# Out:
#     show_id     type                                      title director cast  \
# 3        s4  TV Show                      Jailbirds New Orleans      NaN  NaN
# 10      s11  TV Show        Vendetta: Truth, Lies and The Mafia      NaN  NaN
# 14      s15  TV Show            Crime Stories: India Detectives      NaN  NaN
# 74      s75  TV Show  The World's Most Amazing Vacation Rentals      NaN  NaN
# 123    s124  TV Show                                  Luv Kushh      NaN  NaN
#
#     country          date_added  release_year rating   duration  \
# 3       NaN  September 24, 2021          2021  TV-MA   1 Season
# 10      NaN  September 24, 2021          2021  TV-MA   1 Season
# 14      NaN  September 22, 2021          2021  TV-MA   1 Season
# 74      NaN  September 14, 2021          2021  TV-PG  2 Seasons
# 123     NaN   September 2, 2021          2012  TV-Y7   1 Season
#
#                                              listed_in  \
# 3                               Docuseries, Reality TV
# 10   Crime TV Shows, Docuseries, International TV S...
# 14        British TV Shows, Crime TV Shows, Docuseries
# 74                                          Reality TV
# 123                                           Kids' TV
#
#                                            description
# 3    Feuds, flirtations and toilet talk go down amo...
# 10   Sicily boasts a bold "Anti-Mafia" coalition. B...
# 14   Cameras following Bengaluru police on the job ...
# 74   With an eye for every budget, three travelers ...
# 123  Based on the last book of the epic Ramayana, t...

# %%
url = "https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv"
df = pd.read_csv(url)

# df[["director","country"]][~df.director.isna() & df.country.isna()][:10]

# count_df = (df
#             .groupby(["director", "country"])
#             .size()
#             .reset_index(name='count'))

# count_df


# ---

count_df = (df
            .groupby(["director", "country"]) #.size()
            ).value_counts()

# count_df
# dir_country_main = count_df.loc[count_df.groupby('director')['count'].idxmax()].reset_index(drop=True)
# dir_country_main[:2]

# %%
url = "https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv"
df = pd.read_csv(url)

# from : dir_country_main
# to : df

filled_director_df = pd.merge(df,
                              dir_country_main,
                              on = "director",
                              how = "left" )

filled_director_df = filled_director_df.drop("country_x", axis = 1)
filled_director_df[:10]

filled_director_df[["director", "country_y"]][df["country"].isna()]
# Out:
#                                                director  \
# 2                                       Julien Leclercq
# 3                                                   NaN
# 5                                         Mike Flanagan
# 6                         Robert Cullen, José Luis Ucha
# 10                                                  NaN
# 11                                    Kongkiat Komesiri
# 13                                        Bruno Garotti
# 14                                                  NaN
# 16        Pedro de Echave García, Pablo Azorín Williams
# 18                                           Adam Salky
# 19                                                  NaN
# 20                                      Olivier Megaton
# 22                                       K.S. Ravikumar
# 23                              Alex Woo, Stanley Moore
# 26                                          Rajiv Menon
# 30    Ashwiny Iyer Tiwari, Abhishek Chaubey, Saket C...
# 31                                                  NaN
# 33                                                  NaN
# 34                                                  NaN
# 35                                         Daniel Sandu
# 36                                       Cédric Jimenez
# 45                                          Tyler Greco
# 47                                       Bunmi Ajakaiye
# 64                                      David Yarovesky
# 68    Hanns-Bruno Kammertöns, Vanessa Nöcker, Michae...
# 70                                                  NaN
# 71                                      David A. Vargas
# 74                                                  NaN
# 75                                            Ben Simms
# 77                                        Prakash Satam
# 78                             Delhiprasad Deenadayalan
# 79                             Delhiprasad Deenadayalan
# 80                                          Tomer Eshed
# 83                                                  NaN
# 85                                                  NaN
# 86                                        Thomas Sieben
# 87                                                  NaN
# 88                                        Marcus Clarke
# 89                                                  NaN
# 93                                      Alexis Almström
# 100                                                 NaN
# 102                                         Jason Hehir
# 103                                          Yemi Amodu
# 110                 Luis Alfaro, Javier Gómez Santander
# 112                                      Sara Colangelo
# 113                                       Stephen Herek
# 119                                            JP Habac
# 121                                                 NaN
# 123                                                 NaN
# 128                               Gilles Paquet-Brenner
# 130                               Scott Pleydell-Pearce
# 132                                                 NaN
# 147                                                 NaN
# 148                                     Gerhard Mostert
# 165                                                 NaN
# 180                                         Peter Segal
# 181                                                 NaN
# 185                            Chapman Way, Maclain Way
# 186                                                 NaN
# 187                                                 NaN
# 189                                                 NaN
# 194                                                 NaN
# 196                                         Mark Waters
# 197                                                 NaN
# 213                                                 NaN
# 214                                      Magnus Martens
# 218                                                 NaN
# 221                                         Joshua Rofé
# 222                                       Brad Anderson
# 223                      Mauricio Dias, Tatiana Villela
# 224                                                 NaN
# 225                                                 NaN
# 226                                                 NaN
# 230                                        Rush Sturges
# 234                                                 NaN
# 235                                     Crystal Moselle
# 236                                 Rathindran R Prasad
# 237                                 Rathindran R Prasad
# 238                                 Rathindran R Prasad
# 239                                 Rathindran R Prasad
# 240                                        Han Kwang Il
# 242                                                 NaN
# 243                                                 NaN
# 244                                    Karim El Shenawy
# 245                                                 NaN
# 246                                        Yin Chen-hao
# 248                                                 NaN
# 249                                        Dave Needham
# 250                                    Veronica Velasco
# 252                                    Miguel Alexandre
# 255                                       Michael Harte
# 256                                          Tosin Igho
# 257                                         Mani Ratnam
# 258                                       Alice Filippi
# 260                                                 NaN
# 261                                       Bruno Garotti
# 262                                      Laura Brownson
# 268                                        Moses Inwang
# 287                                    Sakon Tiacharoen
# 294                                    Hideaki Takizawa
# 309                                                 NaN
# 318                         Eva Müller, Michael Schmitt
# 320                                                 NaN
# 331                                                 NaN
# 336                                                 NaN
# 339                               Mag Hsu, Hsu Chih-yen
# 362                                       Kenneth Gyang
# 363                                     Jaume Balagueró
# 364                                                 NaN
# 367                                        Selçuk Metin
# 368                                                 NaN
# 369                                                 NaN
# 371                                        Najwa Najjar
# 372                                        Keishi Otomo
# 373                                       David Charhon
# 375                                     Steven Tsuchida
# 376                                                 NaN
# 379                                                 NaN
# 381                                                 NaN
# 384                                       David Benullo
# 387                                       Laxman Utekar
# 388                     Royale Watkins, Rich Schlansker
# 394                                        Muzi Mthembu
# 395                                        Marcos Bucay
# 396                                     Peter Thorwarth
# 397                                                 NaN
# 398                                       Kim Seong-hun
# 399                                                 NaN
# 400                                                 NaN
# 404                                                 NaN
# 405                                    Sidheswar Shukla
# 406                                       Rajiv Chilaka
# 407                                       Rajiv Chilaka
# 408                                       Rajiv Chilaka
# 409                                       Rajiv Chilaka
# 411                                       Rajiv Chilaka
# 412                                       Rajiv Chilaka
# 413                                       Rajiv Chilaka
# 414                                       Rajiv Chilaka
# 416                                       Rajiv Chilaka
# 417                                         Binayak Das
# 418                       Arpan Sarkar, Shyamal Chaulia
# 419                                       Rajiv Chilaka
# 420                                       Rajiv Chilaka
# 421                            Rajiv Chilaka, Owll Mina
# 422                                       Rajiv Chilaka
# 423                                       Rajiv Chilaka
# 424                                       Rajiv Chilaka
# 427                                       Mahmoud Karim
# 428                                     Kyohei Ishiguro
# 430                                                 NaN
# 431                                                 NaN
# 432   Johane Matte, Andrew L. Schmidt, Francisco Rui...
# 435                                                 NaN
# 438                                     Kathryn Fasegha
# 441                                        Leigh Janiak
# 443                                        Luis Estrada
# 444                                     Garrett Bradley
# 454                                         Tommy Chong
# 455                                     Fred Ouro Preto
# 458                                 Alessandra de Rossi
# 461                                   Alaa Eddine Aljem
# 464                                     Navot Papushado
# 465                                                 NaN
# 466                                                 NaN
# 467                                       Manuel Alcalá
# 468                                       Ricardo Trogi
# 470                                                 NaN
# 471                              Akay Mason, Abosi Ogba
# 475                                      Daniel Růžička
# 476                                      Juraj Šajmovič
# 479                                        Leigh Janiak
# 480                                   Femi D. Ogunsanwo
# 481                                       Douglas Attal
# 482                                                 NaN
# 483                                                 NaN
# 484                                       Kim Joo-hyung
# 485                                      Avi Federgreen
# 487                                                 NaN
# 490                                                 NaN
# 495                                   Tolulope Itegboje
# 497                                                 NaN
# 498                                        Pascal Atuma
# 500                                         Oleg Trofim
# 501                                       Seyi Babatope
# 504                                                 NaN
# 505                    Anurin Nwunembom, Musing Derrick
# 507                                         Udoka Oyeka
# 546                                                 NaN
# 549                                                 NaN
# 550                                        Leigh Janiak
# 552                                        Neri Parenti
# 560                                          Matt Ogens
# 570                                  Chow Hin Yeung Roy
# 571                                                 NaN
# 577                                         Malik Nejer
# 580                                        Shuko Murase
# 586                                        Mary Lambert
# 587   Sidharta Tata, Aco Tenriyagelli, Dian Sastrowa...
# 590                                                 NaN
# 616                                         Mary Harron
# 619                                        Jameel Buari
# 621                                         Shen Leping
# 623                                   Jose Javier Reyes
# 624                                        Jakub Piątek
# 626                                          John Dower
# 629                                         B. T Thomas
# 632                                        Nibal Arakji
# 633                                      Sofie Šustková
# 637       Srijit Mukherji, Vasan Bala, Abhishek Chaubey
# 639                                                 NaN
# 640                                                 NaN
# 641                                                 NaN
# 644                                      Kimmy Gatewood
# 645                                         Tània Balló
# 646                                         Manolo Caro
# 647                                                 NaN
# 649                                    Anurin Nwunembom
# 652                                      Kingsley Ogoro
# 653                                                 NaN
# 658                                                 NaN
# 663                                                 NaN
# 666                                 Ivan Andrew Payawal
# 670                Yoshiyuki Tomino, Yoshikazu Yasuhiko
# 671                Yoshiyuki Tomino, Yoshikazu Yasuhiko
# 672                                    Yoshiyuki Tomino
# 683                                     Michihito Fujii
# 687                                    Karthik Subbaraj
# 689                Yoshiyuki Tomino, Yoshikazu Yasuhiko
# 690                                        Keishi Otomo
# 691                                                 NaN
# 692                                         Hsu Fu-chun
# 693                                      Lucky Kuswandi
# 695                                      Soudade Kaadan
# 697                                                 NaN
# 700                                                 NaN
# 704                                       Achille Brice
# 706                                                 NaN
# 707                                 Sarawut Wichiensarn
# 710                                                 NaN
# 712                                    Michael Lockshin
# 714                                                 NaN
# 715                                                 NaN
# 717                                                 NaN
# 720                                                 NaN
# 725                                                 NaN
# 729                                                 NaN
# 730                                                 NaN
# 732                                                 NaN
# 738                                                 NaN
# 751                                                 NaN
# 759                                         George Ford
# 760                                         George Ford
# 761                                                 NaN
# 771                                          Chiaki Kon
# 781                                       Peter Galison
# 805                                                 NaN
# 806                                      Hidenori Inoue
# 807                                      Hidenori Inoue
# 811                                          Steve Ball
# 815                                     Mika Kaurismäki
# 827                                  Ekene Som Mekwunye
# 829                                       Kevin Johnson
# 831                             José Larraza, Marc Pons
# 832                                           Gary Sing
# 835                                                 NaN
# 841                                           Ray Jiang
# 842                                                 NaN
# 844                                       Daniel Vernon
# 845                                         Steve Gukas
# 847                                                 NaN
# 849                                                 NaN
# 851                                                 NaN
# 852                                                 NaN
# 854                                                 NaN
# 856                                 Uduak-Obong Patrick
# 858                                        Mohamed Diab
# 861                                       Prakash Satam
# 864                                       Milan Luthria
# 875                                    Mae Czarina Cruz
# 886                                    Uzodinma Okpechi
# 888                                                 NaN
# 893                                     Adriano Rudiman
# 897                                            Cai Cong
# 898                                     Samuel Olatunji
# 912                                                 NaN
# 923                                                 NaN
# 925                                                 NaN
# 927                                                 NaN
# 929                                          Roel Reiné
# 936                                                 NaN
# 937                                         Suhas Kadav
# 938                                         Suhas Kadav
# 939                                         Suhas Kadav
# 940                                         Suhas Kadav
# 941                                         Suhas Kadav
# 957                                                 NaN
# 958                                          Tosin Igho
# 960                                         Oriol Paulo
# 961                              Mike Rianda, Jeff Rowe
# 963                                                 NaN
# 964               Robert Pulcini, Shari Springer Berman
# 965                                                 NaN
# 967                                                 NaN
# 987                                      Rindala Kodeih
# 992                                MIKIKO, Daito Manabe
# 1000                                    Ahishor Solomon
# 1005                                                NaN
# 1006                                        Suhas Kadav
# 1007                                        Suhas Kadav
# 1008                                        Suhas Kadav
# 1009                   Akshay Sanjeev Chavan, Sumit Das
# 1010                                                NaN
# 1025                                                NaN
# 1028                                                NaN
# 1038                                                NaN
# 1054                                    Adriano Rudiman
# 1056                                                NaN
# 1071                                        Suhas Kadav
# 1072                                        Suhas Kadav
# 1073                                        Suhas Kadav
# 1074                                        Suhas Kadav
# 1076                                        Suhas Kadav
# 1077                                        Suhas Kadav
# 1078                                        Suhas Kadav
# 1082                                                NaN
# 1092                                                NaN
# 1094                                                NaN
# 1095                                                NaN
# 1096                                      Steve Rolston
# 1116                                                NaN
# 1130                                     Hidenori Inoue
# 1132                                     Hidenori Inoue
# 1159                                    Fermín Muguruza
# 1180                                                NaN
# 1183                                     Taketoshi Sado
# 1193                                    Adriano Rudiman
# 1207                                        Helena Coan
# 1214                               Luis Alejandro Pérez
# 1224                                                NaN
# 1225                                                NaN
# 1235                                                NaN
# 1246                                          Sunny Lau
# 1247                                     Hidenori Inoue
# 1249                Xavier Maingon, Marc-Antoine Hélard
# 1250                                      Milton Kremer
# 1255                                     Hidenori Inoue
# 1262                                                NaN
# 1271                                                NaN
# 1276                                        Jeferson De
# 1289                                       Saron Sakina
# 1299                                                NaN
# 1381                                   Ifeanyi Ikpoenyi
# 1382                                  Chris Eneng Enaji
# 1418                                         Chris Rock
# 1436                    Alejandro Ruax, Ramiro Martínez
# 1442                                                NaN
# 1462                                                NaN
# 1471                                                NaN
# 1482                                                NaN
# 1518                                                NaN
# 1531                                Farishad I. Latjuba
# 1533                                     Picky Talarico
# 1556                                        Eddie Rosas
# 1564                                        Lai Chun-yu
# 1581                                         Steve Ball
# 1585                                                NaN
# 1596                                                NaN
# 1600                                  Darragh O'Connell
# 1652                                       V Vignarajan
# 1668                                                NaN
# 1723                                                NaN
# 1744                                      Estela Renner
# 1745                                                NaN
# 1778                                                NaN
# 1786                                       Antonio Díaz
# 1828                                                NaN
# 1889                                                NaN
# 1890                                                NaN
# 1892                            Alex Woo, Stanley Moore
# 1914                                                NaN
# 1919                                   Mostafa Abu Seif
# 1952                                                NaN
# 1953                                       Ozan Açıktan
# 1956                                                NaN
# 1968                                      Shigeaki Kubo
# 1973                                                NaN
# 1983                                                NaN
# 1986                                     Sekhar Kammula
# 1992                                Kubhaer T. Jethwani
# 2004                                      Steve Bencich
# 2014                                          Shaun Mir
# 2040                                                NaN
# 2058                                                NaN
# 2101                                                NaN
# 2114                                      Prakash Satam
# 2123                                                NaN
# 2128                                         Anna Stone
# 2147                                     Kunle Afolayan
# 2152                                                NaN
# 2164                                      Pascal Amanfo
# 2166                            Stanley Moore, Alex Woo
# 2182                                      Mfanelo Ngoma
# 2194                            Nopparoj Chotmunkongsit
# 2222                                                NaN
# 2236                                                NaN
# 2252                                     Funke Akindele
# 2261                                    Scott Zabielski
# 2263                                                QLF
# 2326                                      Abhijit Panse
# 2335                                                NaN
# 2370                                       Pablo Aulita
# 2394                                                NaN
# 2425                                                NaN
# 2432                                                NaN
# 2436                                     Ahmed Al-Badry
# 2483                                    Fouad Al Shatti
# 2484                                  Fouad El-Mohandes
# 2488                                      Hussein Kamal
# 2489                                      Hussein Kamal
# 2495                                                NaN
# 2535                                     Obaid Alhmoudi
# 2560                             Pedro Flores Maldonado
# 2568                                                NaN
# 2569                                                NaN
# 2574                                                NaN
# 2593                                            Joey So
# 2594                                            Joey So
# 2595                                            Joey So
# 2619                                       Ashraf Fayeq
# 2639                                                NaN
# 2641                                                NaN
# 2699                                                NaN
# 2739                                                NaN
# 2752                                Vijay S. Bhanushali
# 2759                                                NaN
# 2772                                                NaN
# 2774                                                NaN
# 2785                                                NaN
# 2787                                                NaN
# 2811                                            Joey So
# 2812                                            Joey So
# 2814                                            Joey So
# 2831                                      Toyin Abraham
# 2840                                 Trivikram Srinivas
# 2857                                                NaN
# 2858                                      Momoko Kamiya
# 2864                                        Gustavo Ron
# 2884                                   Oyefunke Fayoyin
# 2893                                                NaN
# 2909                                 Avgousta Zourelidi
# 2922                                                NaN
# 2942                                                NaN
# 2982                                                NaN
# 2991                                                NaN
# 3030                                                NaN
# 3056                                                NaN
# 3064                                     Lucas Margutti
# 3072                                          John Lyde
# 3083                                                NaN
# 3086                                                NaN
# 3093                                   Odunlade Adekola
# 3113                                               Falz
# 3115                                        Omoni Oboli
# 3138                                    Fernando Ayllón
# 3154                                     Biodun Stephen
# 3156                                   Robert O. Peters
# 3167                                      Pascal Amanfo
# 3177                                                NaN
# 3199                                                NaN
# 3213                                     Mike Ezuruonye
# 3216                                                NaN
# 3225                                      Prakash Satam
# 3231                                                NaN
# 3257                                                NaN
# 3284                                                NaN
# 3346                                        Manolo Caro
# 3357                                                NaN
# 3361                                                NaN
# 3376                                      Michael Steed
# 3390                                      Prakash Satam
# 3393                                                NaN
# 3394                                                NaN
# 3395                                                NaN
# 3396                                                NaN
# 3397                                                NaN
# 3399                                  Frank Rajah Arase
# 3404                                                NaN
# 3435                                                NaN
# 3436                                   Naoto Amazutsumi
# 3455                                                NaN
# 3469                                                NaN
# 3479                                        Mana Yasuda
# 3492                                B. V. Nandini Reddy
# 3493                                B. V. Nandini Reddy
# 3501                                                NaN
# 3524                                                NaN
# 3539                                                NaN
# 3547                              Rémy Four, Julien War
# 3550                                                NaN
# 3562                                                NaN
# 3568                                   Ashwin Saravanan
# 3570                                   Ashwin Saravanan
# 3592                                                NaN
# 3599                                     Robert Moresco
# 3628                                  Camille Shooshani
# 3635                                       Marcus Raboy
# 3671                                                NaN
# 3674                                                NaN
# 3677                                                NaN
# 3684                                                NaN
# 3710                                                NaN
# 3748                                                NaN
# 3789                                                NaN
# 3796                                                NaN
# 3802                          Mike Diva, Akiva Schaffer
# 3814                                        Sam Cullman
# 3824                                                NaN
# 3837                                                NaN
# 3843                                                NaN
# 3844                                                NaN
# 3845                                                NaN
# 3846                                                NaN
# 3847                                                NaN
# 3848                                                NaN
# 3849                                                NaN
# 3850                                                NaN
# 3851                                                NaN
# 3853                                                NaN
# 3856                                                NaN
# 3880                                                NaN
# 3882                                                NaN
# 3893                                  Quentin Tarantino
# 3895                                   Fab Five Freddie
# 3896                                    Sandra Restrepo
# 3907                             Beyoncé Knowles-Carter
# 3909                                                NaN
# 3933                                   Karthik Subbaraj
# 3947                                    Fernando Ayllón
# 3953                                                NaN
# 3968                                                NaN
# 3976                                                NaN
# 3984                                                NaN
# 3987                                                NaN
# 3996                                                NaN
# 4012                                                NaN
# 4015                                                NaN
# 4025                                        Brian Klein
# 4029                                                NaN
# 4035                                                NaN
# 4049                                    A.R. Murugadoss
# 4055                                                NaN
# 4056                                                NaN
# 4061                                        Rajiv Menon
# 4105                                                NaN
# 4109                                                NaN
# 4149                                                NaN
# 4150                                      Amarjit Virdi
# 4153                                    Manny Rodriguez
# 4156                                   Adam Bhala Lough
# 4171                                                NaN
# 4179                                                NaN
# 4184                                                NaN
# 4199                                                NaN
# 4213                                       Lorena Munoz
# 4215                                                NaN
# 4216                                                NaN
# 4230                                                NaN
# 4234                                      Paul M. Green
# 4242                                       Paul Dugdale
# 4250                                                NaN
# 4258                                    Eduardo Chauvet
# 4263                                                NaN
# 4265                                                NaN
# 4305                                                NaN
# 4318                                        Marek Losey
# 4322                                        Brian Oakes
# 4323                                        Jacob Joice
# 4325                                         Chris Howe
# 4340                                                NaN
# 4344                                                NaN
# 4371                                                NaN
# 4372                                                NaN
# 4389                                                NaN
# 4398                                  Christopher Guest
# 4415                                                NaN
# 4461                                                NaN
# 4471                                     Tinge Krishnan
# 4481                                     S.S. Rajamouli
# 4491                                                NaN
# 4497                                                NaN
# 4511                                                NaN
# 4514                                   Padraic McKinley
# 4520                                                NaN
# 4521                                                NaN
# 4529                                                NaN
# 4534                                                NaN
# 4536                                                NaN
# 4541                                   Anthony Giordano
# 4543                                          Will Yapp
# 4564                                   Shagufta Rafique
# 4566                                     Tinu Pappachan
# 4606                                    Eduardo Chauvet
# 4627                                                NaN
# 4637                                                NaN
# 4640                                                NaN
# 4648                                                NaN
# 4650                                                NaN
# 4654                                                NaN
# 4677                                                NaN
# 4684                                      Todd Biermann
# 4710                                                NaN
# 4717                                                NaN
# 4767                                                NaN
# 4831                                                NaN
# 4832                                                NaN
# 4856                                                NaN
# 4892                                                NaN
# 4894                                                NaN
# 4896                                                NaN
# 4897                   Guillermo Garcia, David Cantolla
# 4900                                                NaN
# 4906                                        Dawn Porter
# 4908                                                NaN
# 4910                                                NaN
# 4913                                                NaN
# 4914                                                NaN
# 4981                                      Yoo Byung-jae
# 4999                                         Ben Wallis
# 5045                                        Lance Bangs
# 5049                                      Michael McKay
# 5068                 Santiago Diaz, Pablo Martin Farina
# 5089                                                NaN
# 5105                                                NaN
# 5109                                                NaN
# 5120                                                NaN
# 5128                                                NaN
# 5145                                                NaN
# 5155                                                NaN
# 5156                                         David Ayer
# 5184                                         Pali Yahya
# 5191                                                NaN
# 5192                                                NaN
# 5193                                                NaN
# 5194                                                NaN
# 5215                                                NaN
# 5216                                                NaN
# 5242                                                NaN
# 5254                                                NaN
# 5256                                       Dylan Howitt
# 5259                                                NaN
# 5281                              José Miguel Contreras
# 5291                                                NaN
# 5335                                     S.S. Rajamouli
# 5336                                     S.S. Rajamouli
# 5338                                     S.S. Rajamouli
# 5339                                     S.S. Rajamouli
# 5352                                                NaN
# 5356                                                NaN
# 5357                                        Maz Jobrani
# 5360                                                NaN
# 5393                                                NaN
# 5401                                                NaN
# 5458                                                NaN
# 5475                                 Christopher Storer
# 5488                                                NaN
# 5554                                  Laurent Bouzereau
# 5734                                    Moto Sakakibara
# 5775                                                NaN
# 5786                                                NaN
# 5787                                                NaN
# 5788                                                NaN
# 5789                                                NaN
# 5790                                                NaN
# 5791                                                NaN
# 5799                                                NaN
# 5838                                                NaN
# 5870                                                NaN
# 5895                                                NaN
# 5919                                                NaN
# 5964                                                NaN
# 5974                                                NaN
# 5989                                                NaN
# 6007                                    Nagesh Kukunoor
# 6016                                       Anggy Umbara
# 6045                                     Ahmad El-Badri
# 6101                                                NaN
# 6173                                   Anirban Majumder
# 6228                                                NaN
# 6265                                                NaN
# 6275                                                NaN
# 6287                                    Tamer Bassiouni
# 6297                                      Rajiv Chilaka
# 6347                                                NaN
# 6360                                                NaN
# 6378                                                NaN
# 6385                                                NaN
# 6389                                                NaN
# 6404                                                NaN
# 6405                                      Momoko Kamiya
# 6406                                      Momoko Kamiya
# 6430                                                NaN
# 6461                   Sidheswar Shukla, Asit Mohapatra
# 6462                    Asit Mohapatra, Shyamal Chaulia
# 6463                    Shyamal Chaulia, Asit Mohapatra
# 6469                                                NaN
# 6471                                         Luis Lopez
# 6504                                                NaN
# 6505                                                NaN
# 6506                                                NaN
# 6507                                                NaN
# 6508                                                NaN
# 6509                                                NaN
# 6520                                                NaN
# 6531                                  Abdul Aziz Hashad
# 6535                                         Ben Steele
# 6594                                Frederick Cipoletti
# 6618                                                NaN
# 6645                                      Rajiv Chilaka
# 6660                                                NaN
# 6679                                     Federico Lemos
# 6684                        Hugues Nancy, Fabien Beziat
# 6685                                     Nils Tavernier
# 6693                                                NaN
# 6697                                                NaN
# 6709                                                NaN
# 6718                                          James Lee
# 6741                                                NaN
# 6761                                       Keith Malloy
# 6763                                                NaN
# 6773                                                NaN
# 6857                                                NaN
# 6906                                                NaN
# 6926                                                NaN
# 6989                                 Anindya Chatterjee
# 7001                                     Federico Lemos
# 7017                                                NaN
# 7033                                                NaN
# 7045                              Maria Demeshkina Peek
# 7104                                      Ismail Farouk
# 7108                                      Young Jun Lee
# 7116                                                NaN
# 7133                                     Radhu Karmakar
# 7138                                                NaN
# 7146                                Susannah Heath-Eves
# 7196                                                NaN
# 7209                                    Steve Greenwood
# 7214                                                NaN
# 7222                                                NaN
# 7226                                                NaN
# 7227                        Munjal Shroff, Tilak Shetty
# 7228                        Munjal Shroff, Tilak Shetty
# 7229                                       Tilak Shetty
# 7231                                       Tilak Shetty
# 7232                                                NaN
# 7233                        Munjal Shroff, Tilak Shetty
# 7235                                                NaN
# 7243                                      Suresh Pillai
# 7255                                                NaN
# 7278                                         Ron Myrick
# 7287                                                NaN
# 7289                Anders Falck, Stinus Morell Vithner
# 7291                                                NaN
# 7310                                    Ellen Weissbrod
# 7317                                      Prakash Satam
# 7318                                                NaN
# 7319                                      Prakash Satam
# 7338                                                NaN
# 7339                              Ignacio López Escrivá
# 7349                                                NaN
# 7392                                                NaN
# 7405                                      Nathan Landeg
# 7414                                         Eric Drath
# 7438                                                NaN
# 7446                                                NaN
# 7455                                                NaN
# 7483                                                NaN
# 7540                                                NaN
# 7543                                    Wenn V. Deramas
# 7550                                     Moataz El Tony
# 7562                                      Gene Quintano
# 7586                                                NaN
# 7624                                                NaN
# 7632                                                NaN
# 7645                                          Poj Arnon
# 7673                                     Tiller Russell
# 7733                                 Karan Lalit Butani
# 7760                                                NaN
# 7762                                                NaN
# 7777                                                NaN
# 7779                                                NaN
# 7795                                     Bhavik Thakore
# 7812                                                NaN
# 7813                                                NaN
# 7815                                                NaN
# 7838                                                NaN
# 7848                    Clementine Malpas, Leslie Knott
# 7862                                                NaN
# 7893                                 Shweta Basu Prasad
# 7929                                   Anirban Majumder
# 7942                                                NaN
# 8109                                                NaN
# 8137                                                NaN
# 8160                                       Steve Barron
# 8180                                                NaN
# 8199                                                NaN
# 8206                                                NaN
# 8230                                    Husam El-Gohari
# 8328                                        David Batty
# 8329                                        David Batty
# 8347                                                NaN
# 8368                                                NaN
# ...
# 3907                                            NaN
# 3909                                            NaN
# 3933                                          India
# 3947                                       Colombia
# 3953                                            NaN
# 3968                                            NaN
# 3976                                            NaN
# 3984                                            NaN
# 3987                                            NaN
# 3996                                            NaN
# 4012                                            NaN
# 4015                                            NaN
# 4025                                 United Kingdom
# 4029                                            NaN
# 4035                                            NaN
# 4049                                          India
# 4055                                            NaN
# 4056                                            NaN
# 4061                                          India
# 4105                                            NaN
# 4109                                            NaN
# 4149                                            NaN
# 4150                                            NaN
# 4153                                  United States
# 4156                                            NaN
# 4171                                            NaN
# 4179                                            NaN
# 4184                                            NaN
# 4199                                            NaN
# 4213                                            NaN
# 4215                                            NaN
# 4216                                            NaN
# 4230                                            NaN
# 4234                                            NaN
# 4242                                 United Kingdom
# 4250                                            NaN
# 4258                                            NaN
# 4263                                            NaN
# 4265                                            NaN
# 4305                                            NaN
# 4318                                            NaN
# 4322                                  United States
# 4323                                            NaN
# 4325                                 United Kingdom
# 4340                                            NaN
# 4344                                            NaN
# 4371                                            NaN
# 4372                                            NaN
# 4389                                            NaN
# 4398                                  United States
# 4415                                            NaN
# 4461                                            NaN
# 4471                                            NaN
# 4481                                          India
# 4491                                            NaN
# 4497                                            NaN
# 4511                                            NaN
# 4514                                            NaN
# 4520                                            NaN
# 4521                                            NaN
# 4529                                            NaN
# 4534                                            NaN
# 4536                                            NaN
# 4541                                  United States
# 4543                                 United Kingdom
# 4564                                            NaN
# 4566                                            NaN
# 4606                                            NaN
# 4627                                            NaN
# 4637                                            NaN
# 4640                                            NaN
# 4648                                            NaN
# 4650                                            NaN
# 4654                                            NaN
# 4677                                            NaN
# 4684                                            NaN
# 4710                                            NaN
# 4717                                            NaN
# 4767                                            NaN
# 4831                                            NaN
# 4832                                            NaN
# 4856                                            NaN
# 4892                                            NaN
# 4894                                            NaN
# 4896                                            NaN
# 4897                                            NaN
# 4900                                            NaN
# 4906                                            NaN
# 4908                                            NaN
# 4910                                            NaN
# 4913                                            NaN
# 4914                                            NaN
# 4981                                            NaN
# 4999                                  United States
# 5045                                  United States
# 5049                                  United States
# 5068                                            NaN
# 5089                                            NaN
# 5105                                            NaN
# 5109                                            NaN
# 5120                                            NaN
# 5128                                            NaN
# 5145                                            NaN
# 5155                                            NaN
# 5156                                  United States
# 5184                                            NaN
# 5191                                            NaN
# 5192                                            NaN
# 5193                                            NaN
# 5194                                            NaN
# 5215                                            NaN
# 5216                                            NaN
# 5242                                            NaN
# 5254                                            NaN
# 5256                                            NaN
# 5259                                            NaN
# 5281                                            NaN
# 5291                                            NaN
# 5335                                          India
# 5336                                          India
# 5338                                          India
# 5339                                          India
# 5352                                            NaN
# 5356                                            NaN
# 5357                                            NaN
# 5360                                            NaN
# 5393                                            NaN
# 5401                                            NaN
# 5458                                            NaN
# 5475                                  United States
# 5488                                            NaN
# 5554                                            NaN
# 5734                                            NaN
# 5775                                            NaN
# 5786                                            NaN
# 5787                                            NaN
# 5788                                            NaN
# 5789                                            NaN
# 5790                                            NaN
# 5791                                            NaN
# 5799                                            NaN
# 5838                                            NaN
# 5870                                            NaN
# 5895                                            NaN
# 5919                                            NaN
# 5964                                            NaN
# 5974                                            NaN
# 5989                                            NaN
# 6007                                          India
# 6016                                            NaN
# 6045                                          Egypt
# 6101                                            NaN
# 6173                                            NaN
# 6228                                            NaN
# 6265                                            NaN
# 6275                                            NaN
# 6287                                            NaN
# 6297                                          India
# 6347                                            NaN
# 6360                                            NaN
# 6378                                            NaN
# 6385                                            NaN
# 6389                                            NaN
# 6404                                            NaN
# 6405                                            NaN
# 6406                                            NaN
# 6430                                            NaN
# 6461                                            NaN
# 6462                                            NaN
# 6463                                            NaN
# 6469                                            NaN
# 6471                                            NaN
# 6504                                            NaN
# 6505                                            NaN
# 6506                                            NaN
# 6507                                            NaN
# 6508                                            NaN
# 6509                                            NaN
# 6520                                            NaN
# 6531                                            NaN
# 6535                                            NaN
# 6594                                            NaN
# 6618                                            NaN
# 6645                                          India
# 6660                                            NaN
# 6679                                            NaN
# 6684                                            NaN
# 6685                                            NaN
# 6693                                            NaN
# 6697                                            NaN
# 6709                                            NaN
# 6718                                            NaN
# 6741                                            NaN
# 6761                                            NaN
# 6763                                            NaN
# 6773                                            NaN
# 6857                                            NaN
# 6906                                            NaN
# 6926                                            NaN
# 6989                                            NaN
# 7001                                            NaN
# 7017                                            NaN
# 7033                                            NaN
# 7045                                            NaN
# 7104                                          Egypt
# 7108                                            NaN
# 7116                                            NaN
# 7133                                            NaN
# 7138                                            NaN
# 7146                                            NaN
# 7196                                            NaN
# 7209                                            NaN
# 7214                                            NaN
# 7222                                            NaN
# 7226                                            NaN
# 7227                                            NaN
# 7228                                            NaN
# 7229                                          India
# 7231                                          India
# 7232                                            NaN
# 7233                                            NaN
# 7235                                            NaN
# 7243                                            NaN
# 7255                                            NaN
# 7278                                  United States
# 7287                                            NaN
# 7289                                            NaN
# 7291                                            NaN
# 7310                                            NaN
# 7317                                            NaN
# 7318                                            NaN
# 7319                                            NaN
# 7338                                            NaN
# 7339                                            NaN
# 7349                                            NaN
# 7392                                            NaN
# 7405                                            NaN
# 7414                                            NaN
# 7438                                            NaN
# 7446                                            NaN
# 7455                                            NaN
# 7483                                            NaN
# 7540                                            NaN
# 7543                                    Philippines
# 7550                                            NaN
# 7562                                            NaN
# 7586                                            NaN
# 7624                                            NaN
# 7632                                            NaN
# 7645                                       Thailand
# 7673                                  United States
# 7733                                            NaN
# 7760                                            NaN
# 7762                                            NaN
# 7777                                            NaN
# 7779                                            NaN
# 7795                                            NaN
# 7812                                            NaN
# 7813                                            NaN
# 7815                                            NaN
# 7838                                            NaN
# 7848                                            NaN
# 7862                                            NaN
# 7893                                            NaN
# 7929                                            NaN
# 7942                                            NaN
# 8109                                            NaN
# 8137                                            NaN
# 8160                                            NaN
# 8180                                            NaN
# 8199                                            NaN
# 8206                                            NaN
# 8230                                          Egypt
# 8328         United Kingdom, United States, Morocco
# 8329         United Kingdom, United States, Morocco
# 8347                                            NaN
# 8368                                            NaN
# 8376                                            NaN
# 8392                                            NaN
# 8433                                  United States
# 8450                                            NaN
# 8481                                          Egypt
# 8544                                            NaN
# 8585                                          Egypt
# 8592                                            NaN
# 8593                                            NaN
# 8602                                            NaN
# 8609                                            NaN
# 8622                                  United States
# 8679                                            NaN
# 8690                                            NaN
# 8718                                            NaN
# 8759                                            NaN
# 8783                                            NaN
# 8785                                            NaN
# 8803                                            NaN

# %%
url = "https://d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/000/940/original/netflix.csv"
df = pd.read_csv(url)

df['listed_in'] = (df['listed_in']
                  .replace('nan', pd.NA)
                  .apply(lambda x: str(x).split(', ') if pd.notna(x) else [pd.NA])
                  )

comb_df = (df[["show_id","director","country","listed_in"]]
                   .explode('listed_in')
                   .reset_index(drop=True)
                  )
